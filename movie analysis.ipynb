# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
m = pd.read_csv(r"C:\Users\hp\Downloads\imdb-5000-movie-dataset\movie_metadata.csv")
oridata=m
m
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
m.describe
# Out:
# <bound method NDFrame.describe of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
m.shape
# Out:
# (5043, 28)

# %% [markdown]
# # Cleaning the data

# %%
m.isnull().sum(axis= 0).sort_values(ascending=False)
# Out:
# gross                        884
# budget                       492
# aspect_ratio                 329
# content_rating               303
# plot_keywords                153
# title_year                   108
# director_name                104
# director_facebook_likes      104
# num_critic_for_reviews        50
# actor_3_name                  23
# actor_3_facebook_likes        23
# num_user_for_reviews          21
# color                         19
# duration                      15
# facenumber_in_poster          13
# actor_2_name                  13
# actor_2_facebook_likes        13
# language                      12
# actor_1_name                   7
# actor_1_facebook_likes         7
# country                        5
# cast_total_facebook_likes      0
# num_voted_users                0
# movie_title                    0
# movie_imdb_link                0
# genres                         0
# imdb_score                     0
# movie_facebook_likes           0
# dtype: int64

# %%
m.isnull().sum(axis= 1).sort_values(ascending=False)
# Out:
# 279     15
# 4       14
# 4945    11
# 2241    11
# 2342    10
#         ..
# 1703     0
# 1702     0
# 1701     0
# 1700     0
# 5042     0
# Length: 5043, dtype: int64

# %% [markdown]
# m.isnull().sum(axis= 0).sort_values(ascending=False)/len(m)*100

# %%
m.isnull().sum(axis= 0).sort_values(ascending=False)/len(m)*100
# Out:
# gross                        17.529248
# budget                        9.756098
# aspect_ratio                  6.523895
# content_rating                6.008328
# plot_keywords                 3.033908
# title_year                    2.141582
# director_name                 2.062265
# director_facebook_likes       2.062265
# num_critic_for_reviews        0.991473
# actor_3_name                  0.456078
# actor_3_facebook_likes        0.456078
# num_user_for_reviews          0.416419
# color                         0.376760
# duration                      0.297442
# facenumber_in_poster          0.257783
# actor_2_name                  0.257783
# actor_2_facebook_likes        0.257783
# language                      0.237954
# actor_1_name                  0.138806
# actor_1_facebook_likes        0.138806
# country                       0.099147
# cast_total_facebook_likes     0.000000
# num_voted_users               0.000000
# movie_title                   0.000000
# ...

# %% [markdown]
# ## droping unecessary columns

# %%
  m=m.drop(['color',
    'director_facebook_likes',
    'actor_1_facebook_likes',
    'actor_2_facebook_likes',
    'actor_3_facebook_likes',
    'actor_2_name',
    'cast_total_facebook_likes',
    'actor_3_name',
    'duration',
    'facenumber_in_poster',
    'content_rating',
    'country',
    'movie_imdb_link',
    'aspect_ratio',
    'plot_keywords'],axis=1)

# %%
m
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
round(m.isnull().sum().sort_values(ascending=False)/len(m)*100,2)
# Out:
# gross                     17.53
# budget                     9.76
# title_year                 2.14
# director_name              2.06
# num_critic_for_reviews     0.99
# num_user_for_reviews       0.42
# language                   0.24
# actor_1_name               0.14
# genres                     0.00
# movie_title                0.00
# num_voted_users            0.00
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %%
 m=m[m['gross'].notnull()]
 m=m[m['budget'].notnull()]

# %%
round(m.isnull().sum().sort_values(ascending=False)/len(m)*100,2)
# Out:
# actor_1_name              0.08
# language                  0.08
# num_critic_for_reviews    0.03
# director_name             0.00
# gross                     0.00
# genres                    0.00
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %%
m.isnull().sum(axis= 1).sort_values(ascending=False)
# Out:
# 4502    1
# 4720    1
# 4110    1
# 4837    1
# 4711    1
#        ..
# 1375    0
# 1376    0
# 1377    0
# 1378    0
# 5042    0
# Length: 3891, dtype: int64

# %% [markdown]
# ## droping unecessary rows

# %%
(m.isnull().sum(axis= 1).sort_values(ascending=False)>5).sum()
# Out:
# 0

# %%
m=m[m.isnull().sum(axis= 1).sort_values(ascending=False)<=5]
m
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# # fill NaN values

# %%
round(m.isnull().sum(axis= 0).sort_values(ascending=False)/len(m)*100,2)
# Out:
# actor_1_name              0.08
# language                  0.08
# num_critic_for_reviews    0.03
# director_name             0.00
# gross                     0.00
# genres                    0.00
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %%
m.groupby('language').language.count().sort_values(ascending=False)
# Out:
# language
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Portuguese       5
# Korean           5
# Norwegian        4
# Dutch            3
# Persian          3
# Danish           3
# Hebrew           3
# Thai             3
# Indonesian       2
# Aboriginal       2
# Dari             2
# Czech            1
# Vietnamese       1
# Aramaic          1
# Telugu           1
# Swedish          1
# Bosnian          1
# Russian          1
# Romanian         1
# Arabic           1
# Icelandic        1
# Dzongkha         1
# None             1
# Mongolian        1
# Maya             1
# Filipino         1
# Hungarian        1
# Kazakh           1
# Zulu             1
# Name: language, dtype: int64

# %%
m.language.describe()
# Out:
# count        3888
# unique         38
# top       English
# freq         3707
# Name: language, dtype: object

# %%
m.language= m.language.fillna('English')

# %%
round(m.isnull().sum(axis= 0).sort_values(ascending=False)/len(m)*100,2)
# Out:
# actor_1_name              0.08
# num_critic_for_reviews    0.03
# director_name             0.00
# gross                     0.00
# genres                    0.00
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# ## check the number of retained rows

# %%
len(m)/len(oridata)*100
# Out:
# 77.15645449137418

# %% [markdown]
# ## now we are going to change the unit of columns

# %%
m['budget']=m['budget']/1000000
m['gross']=m['gross']/1000000

# %%
m
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# ## finding the movies with highest profit

# %%
m['profit']=m['gross']-m['budget']
m
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
m.sort_values(by='profit',ascending=False)
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
 top10=m.sort_values(by='profit',ascending=False).head(10)
 top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# ## dropping the duplicates values

# %%
m.drop_duplicates(keep='first',inplace=True)
m
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
 top10=m.sort_values(by='profit',ascending=False).head(10)
 top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
# 439           Gary Ross                   673.0  407.999255
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# ## now we are going to find imdb top 250

# %%
m[m['num_voted_users']>25000]
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 4977    Morgan Spurlock                   193.0   11.529368
# 5008        Kevin Smith                   136.0    3.151130
# 5012         David Ayer                   233.0   10.499968
# 5033      Shane Carruth                   143.0    0.424760
# 5035   Robert Rodriguez                    56.0    2.040920
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
imdb_top_250=m[m['num_voted_users']>25000].sort_values(by='imdb_score',ascending=False).head(250)
imdb_top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 4931           John Carney                   232.0    9.437933
# 2605               Ang Lee                   287.0  128.067808
# 3029      David O. Russell                   410.0   93.571803
# 2177            Tim Burton                   111.0   56.362352
# 2487          George Cukor                    82.0   72.000000
#
#                             genres    actor_1_name  \
# 1937                   Crime|Drama  Morgan Freeman
# 3466                   Crime|Drama       Al Pacino
# 2837                   Crime|Drama  Robert De Niro
# ...

# %%
imdb_top_250['Rank']=imdb_top_250['imdb_score'].rank(method='first',ascending=False)
imdb_top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 4931           John Carney                   232.0    9.437933
# 2605               Ang Lee                   287.0  128.067808
# 3029      David O. Russell                   410.0   93.571803
# 2177            Tim Burton                   111.0   56.362352
# 2487          George Cukor                    82.0   72.000000
#
#                             genres    actor_1_name  \
# 1937                   Crime|Drama  Morgan Freeman
# 3466                   Crime|Drama       Al Pacino
# 2837                   Crime|Drama  Robert De Niro
# ...

# %%
imdb_top_250[imdb_top_250['language']!='English']
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    6.100000
# 4747                    Akira Kurosawa                   153.0    0.269061
# 4029                Fernando Meirelles                   214.0    7.563397
# 2373                    Hayao Miyazaki                   246.0   10.049886
# 4259  Florian Henckel von Donnersmarck                   215.0   11.284657
# 4921                      Majid Majidi                    46.0    0.925402
# 2323                    Hayao Miyazaki                   174.0    2.298191
# 2970                 Wolfgang Petersen                    96.0   11.433134
# 4105                    Chan-wook Park                   305.0    2.181290
# 4659                    Asghar Farhadi                   354.0    7.098492
# 1329                    S.S. Rajamouli                    44.0    6.498000
# ...

# %% [markdown]
# ## finding the best directors list

# %%
top10director=m.groupby('director_name').imdb_score.mean().sort_values(ascending=False).head(10)
top10director
# Out:
# director_name
# Charles Chaplin          8.600000
# Tony Kaye                8.600000
# Alfred Hitchcock         8.500000
# Ron Fricke               8.500000
# Damien Chazelle          8.500000
# Majid Majidi             8.500000
# Sergio Leone             8.433333
# Christopher Nolan        8.425000
# S.S. Rajamouli           8.400000
# Marius A. Markevicius    8.400000
# Name: imdb_score, dtype: float64

# %% [markdown]
# ## finding the top genres

# %%
TempGenre=m.genres.str.split('|',expand=True).iloc[:,0:2]
TempGenre.columns=['genre_1',"genre_2"]
TempGenre.genre_2.fillna(TempGenre.genre_1,inplace=True)
TempGenre
# Out:
#           genre_1      genre_2
# 0          Action    Adventure
# 1          Action    Adventure
# 2          Action    Adventure
# 3          Action     Thriller
# 5          Action    Adventure
# ...           ...          ...
# 5033        Drama       Sci-Fi
# 5034     Thriller     Thriller
# 5035       Action        Crime
# 5037       Comedy        Drama
# 5042  Documentary  Documentary
#
# [3856 rows x 2 columns]

# %%
m=pd.concat([m,TempGenre],axis=1)
m
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
m.groupby(['genre_1','genre_2']).gross.mean().sort_values(ascending=False).head(10)
# Out:
# genre_1    genre_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Family       118.919540
#            Animation    116.998550
# Action     Adventure    109.595465
# Fantasy    Mystery      100.614858
# Animation  Comedy        97.781776
# Action     Animation     92.680515
# Musical    Romance       92.084000
# Adventure  Fantasy       90.617977
# Name: gross, dtype: float64

# %% [markdown]
# ## Finding the critic-favorite and audience-favorite actors

# %%
Meryl_Streep=m[m['actor_1_name']=='Meryl Streep']
Leo_Caprio=m[m['actor_1_name']=='Leonardo DiCaprio']
Brad_Pitt=m[m['actor_1_name']=='Brad Pitt']

# %%
Combined=Meryl_Streep.append([Leo_Caprio,Brad_Pitt])
Combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 410            Nancy Meyers                   187.0  112.703470
# 1106          Curtis Hanson                    42.0   46.815748
# 1204            Nora Ephron                   252.0   94.125426
# 1408          David Frankel                   208.0  124.732962
# 1483         Robert Redford                   227.0   14.998070
# 1575         Sydney Pollack                    66.0   87.100000
# 1618          David Frankel                   234.0   63.536011
# 1674          Carl Franklin                    64.0   23.209440
# 1925         Stephen Daldry                   174.0   41.597830
# 2781         Phyllida Lloyd                   331.0   29.959436
# 3135          Robert Altman                   211.0   20.338609
# 26            James Cameron                   315.0  658.672302
# 50             Baz Luhrmann                   490.0  144.812796
# 97        Christopher Nolan                   642.0  292.568851
# ...

# %%
Combined.groupby('actor_1_name').num_critic_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            245.000000
# Leonardo DiCaprio    330.190476
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
Combined.num_critic_for_reviews.astype('int')
# Out:
# 410     187
# 1106     42
# 1204    252
# 1408    208
# 1483    227
# 1575     66
# 1618    234
# 1674     64
# 1925    174
# 2781    331
# 3135    211
# 26      315
# 50      490
# 97      642
# 179     556
# 257     267
# 296     765
# 307     166
# 308     606
# 326     233
# 361     352
# 452     490
# 641     238
# 911     194
# 990     118
# 1114    323
# 1422     83
# 1453    392
# 1560     63
# 2067     45
# 2757    106
# 3476    490
# 101     362
# 147     220
# 254     198
# 255     233
# 382     142
# 400     186
# 470     406
# 611      76
# 683     315
# 792      98
# 940     120
# 1490    584
# 1722    273
# 2204    285
# 2333    131
# 2682    414
# 2898    122
# Name: num_critic_for_reviews, dtype: int32

# %%
Combined.groupby('actor_1_name').num_user_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            742.352941
# Leonardo DiCaprio    914.476190
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %%
Combined.groupby('actor_1_name')[['num_critic_for_reviews','num_user_for_reviews']].mean()
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Brad Pitt                      245.000000            742.352941
# Leonardo DiCaprio              330.190476            914.476190
# Meryl Streep                   181.454545            297.181818

# %% [markdown]
# # graphical analysis
# finding the correlation among the attributes

# %%
# heat map
plt.figure(figsize=(14,12))
sns.heatmap(imdb_top_250.corr(),annot=True,cmap="terrain")
# Out:
# <Axes: >

# %%
sns.pairplot(data=imdb_top_250)

# %%
imdb_top_250.hist(figsize=(12,12), layout=(4,3));

# %%
sns.barplot(data=imdb_top_250, x="num_voted_users", y='num_user_for_reviews')
# Out:
# <Axes: xlabel='num_voted_users', ylabel='num_user_for_reviews'>

# %%
sns.scatterplot(x='num_voted_users', y='num_user_for_reviews', data=imdb_top_250)
# Out:
# <Axes: xlabel='num_voted_users', ylabel='num_user_for_reviews'>
